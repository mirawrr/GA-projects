# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# <span style='color:blue'>
#
# The COVID-19 pandemic had reportedly reduced the overall participation rates in SAT & ACT tests in the United States, as many test sessions had to be cancelled due to school/test centre closures or reduced testing capacity. [(College Board](https://newsroom.collegeboard.org/sat-program-results-capture-impact-of-covid-on-class-of-2021)[ & Forbes)](https://www.forbes.com/sites/michaeltnietzel/2021/10/13/the-number-of-students-taking-the-act-dropped-22-this-year/?sh=5a60caf7c60a)
#
# As an employee of a consulting firm that specialises in the education sector, my team has been tasked to analyse trends in SAT and ACT participation rates and aggregated scores for each state in the US from 2019 to 2021. Based on the findings, we will provide recommendations to the College Board and ACT Inc. on their resource prioritisation strategy to improve participation rates in future SAT/ACT tests especially for states that were most adversely affected due to the pandemic.
#
# Key Question:
# <ul>
#
# - How should College Board and ACT In. re-allocate their resources to improve participation rates in future tests?
#
# Sub Questions:
#
# - Which states had high participation rates before the pandemic?
# - Which states had the greatest decline in exam participation rates/ aggregated scores during the pandemic?
# - Which states should be allocated more resources?
#
# </ul>
#
# </span>

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# ### <span style='color:blue'>Datasets Used</span>
#
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2020.csv`](./data/act_2020.csv): 2020 ACT Scores by State ([*source*](https://nces.ed.gov/programs/digest/d20/tables/dt20_226.60.asp))
# * [`act_2021.csv`](./data/act_2021.csv): 2021 ACT Scores by State ([*source*](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows))
#
#
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2020.csv`](./data/sat_2020.csv): 2020 SAT Scores by State ([*source*](https://nces.ed.gov/programs/digest/d20/tables/dt20_226.40.asp))
# * [`sat_2021.csv`](./data/sat_2021.csv): 2021 SAT Scores by State ([*source*](https://blog.prepscholar.com/average-sat-scores-by-state-most-recent))

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# <span style='color:blue'>
#
# **Background Information**
#
# * Range of SAT scores: 400 to 1600
# * Range of ACT scores: 1 to 36
#
# During the pandemic period, several schools waived SAT/ACT requirement for college entrance applications as the pandemic had disrupted testing for many applicants. In 2022, as COVID-19 is becoming endemic and school and testing centers have resumed operations, some schools such as MIT have reinstated the SAT/ACT requirement. [NY Times](https://www.nytimes.com/2022/03/28/education/mit-sat-act-scores-admission.html)
# </span>

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def my_mean(values):
    return sum(values)/len(values)

# %%
my_mean([1,2,3,4,5])
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def my_std_dev(values):
    n = len(values)
    mean = sum(values) / n
    var = sum((value - my_mean(values))**2 for value in values) / n
    std_dev = var ** 0.5
    return std_dev

# %%
my_std_dev([8,10,11,4,6,16])
# Out:
# 3.8477987935383986

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def str_to_float(string):
    if '%' in string:
        return float(string.replace('%',''))/ 100
    else:
        return float(string) / 100

# %%
num = str_to_float('50')
print(num)
print(type(num))
# Out:
# 0.5
# <class 'float'>

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### <span style='color:steelblue'> 2019 Datasets: Import & Cleaning </span>

# %%
#import 2019 datasets

sat_2019 = pd.read_csv("../data/sat_2019.csv")
act_2019 = pd.read_csv("../data/act_2019.csv")

# %%
#print first 5 rows of sat_2019 and act_2019 

sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#print first 5 rows of act_2019 
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#retrieve details on sat_2019 dataset
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
#retrieve details on act_2019 dataset
#noted that the two datasets do not have the same total no. of entries. The non-overlapping rows are identified and will be dropped later.

act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %%
#find out the index of the rows to drop
print('sat_2019: \n')
print(sat_2019.loc[(sat_2019['State'] == 'Puerto Rico') | (sat_2019['State'] == 'Virgin Islands')].head())
print('\n')
print('act_2019: \n')
print(act_2019.loc[(act_2019['State'] == 'National')].head())
# Out:
# sat_2019:
#
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                  —   483   462    944
# 47  Virgin Islands                  —   490   445    935
#
#
# act_2019:
#
#        State Participation  Composite
# 51  National           52%       20.7

# %%
#remove rows 39 (Puerto Rico) and 47 (Virgin Islands) rows from sat_2019
#remove row 51 (National) from act_2019

sat_2019 = sat_2019.drop(labels=[39,47],axis=0)
act_2019 = act_2019.drop(labels=[51],axis=0)

# %%
#verify that no. of rows for sat_2019 and act_2019 are now the same. 
#However, the participation rate value for both datasets are of object datatype.

sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.4+ KB

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   Composite      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
#convert participation rate (string) to float datatype using function str_to_float

sat_2019['Participation Rate'] = sat_2019['Participation Rate'].astype(str).apply(str_to_float)
act_2019['Participation'] = act_2019['Participation'].astype(str).apply(str_to_float)

# %%
#verify that the participation rate values are converted into the right float format
sat_2019.head()
#act_2019.head()
# Out:
#         State  Participation Rate  EBRW  Math  Total
# 0     Alabama                0.07   583   560   1143
# 1      Alaska                0.41   556   541   1097
# 2     Arizona                0.31   569   565   1134
# 3    Arkansas                0.06   582   559   1141
# 4  California                0.63   534   531   1065

# %%
#rename columns > change to lowercase with underscores

sat_2019.columns = sat_2019.columns.str.lower()
act_2019.columns = act_2019.columns.str.lower()

sat_2019.rename(columns={
    'state' : 'state',
    'participation rate' : 'participation_sat_2019',
    'ebrw' : 'ebrw_sat_2019',
    'math' : 'math_sat_2019',
    'total' : 'total_sat_2019'
}, inplace = True)

act_2019.rename(columns={
    'state' : 'state',
    'participation' : 'participation_act_2019',
    'composite' : 'composite_act_2019'
},inplace = True)

#verify that the column names have been changed correctly
sat_2019.columns
#act_2019.columns
# Out:
# Index(['state', 'participation_sat_2019', 'ebrw_sat_2019', 'math_sat_2019',
#        'total_sat_2019'],
#       dtype='object')

# %%
#check for duplicates

dup_sat_2019 = len(sat_2019) - len(sat_2019.drop_duplicates())
dup_act_2019 = len(act_2019) - len(act_2019.drop_duplicates())

print (f'There are {dup_sat_2019} duplicate(s) in sat_2019.')
print(f'There are {dup_act_2019} duplicate(s) in act_2019.')
# Out:
# There are 0 duplicate(s) in sat_2019.
# There are 0 duplicate(s) in act_2019.

# %%
# concat 2019 datasets on 'state' key
merged_2019 = pd.merge(sat_2019,act_2019,on='state')
merged_2019
# Out:
#                    state  participation_sat_2019  ebrw_sat_2019  \
# 0                Alabama                    0.07            583
# 1                 Alaska                    0.41            556
# 2                Arizona                    0.31            569
# 3               Arkansas                    0.06            582
# 4             California                    0.63            534
# 5               Colorado                    1.00            518
# 6            Connecticut                    1.00            529
# 7               Delaware                    1.00            499
# 8   District of Columbia                    0.94            495
# 9                Florida                    1.00            516
# 10               Georgia                    0.71            538
# 11                Hawaii                    0.54            550
# 12                 Idaho                    1.00            505
# 13              Illinois                    1.00            509
# ...

# %% [markdown]
# ## <span style='color:steelblue'> 2020 Datasets: Import & Cleaning </span>

# %%
#import 2020 datasets
sat_2020 = pd.read_csv("../data/sat_2020.csv", encoding='latin1')
act_2020 = pd.read_csv("../data/act_2020.csv")

# %%
#print first 5 rows of sat_2020 
sat_2020.head()
# Out:
#         State Participation Rate  Mean EBRW  Mean Math  Mean Total
# 0     Alabama                 7%        576        551        1127
# 1      Alaska                37%        555        543        1098
# 2     Arizona                29%        571        568        1139
# 3    Arkansas                 4%        590        567        1157
# 4  California                67%        527        522        1049

# %%
#print first 5 rows of act_2020 
act_2020.head()
# Out:
#          State Participation  Composite score
# 0     Alabama           100%             18.8
# 1      Alaska            33%             20.1
# 2     Arizona            71%             19.1
# 3    Arkansas           100%             19.0
# 4  California            19%             23.3

# %%
#find out the index of the rows to drop
print('sat_2020: \n')
print(sat_2020.loc[(sat_2020['State'] == 'Puerto Rico') | (sat_2020['State'] == 'Virgin Islands')].head())
print('\n')
print('act_2020: \n')
print(act_2020.loc[(act_2020['State'] == 'National')].head())
# Out:
# sat_2020:
#
#              State Participation Rate  Mean EBRW  Mean Math  Mean Total
# 39     Puerto Rico                          511        481         993
# 47  Virgin Islands                          474        437         912
#
#
# act_2020:
#
#        State Participation  Composite score
# 51  National           46%             20.7

# %%
#remove rows 39 (Puerto Rico) and 47 (Virgin Islands) rows from sat_2020
#remove row 51 (National) from act_2020

sat_2020 = sat_2020.drop(labels=[39,47],axis=0)
act_2020 = act_2020.drop(labels=[51],axis=0)

# %%
#verify that no. of rows for both sat_2020 and act_2020 are now the same. 
#However, the participation rate value for both datasets are of object datatype.
sat_2020.info()
#act_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   Mean EBRW           51 non-null     int64
#  3   Mean Math           51 non-null     int64
#  4   Mean Total          51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.4+ KB

# %%
#convert participation rate (string) to float datatype using function str_to_float

sat_2020['Participation Rate'] = sat_2020['Participation Rate'].astype(str).apply(str_to_float)
act_2020['Participation'] = act_2020['Participation'].astype(str).apply(str_to_float)

# %%
#verify that the participation rate values are converted into the right float format
sat_2020.head()
#act_2020.head()
# Out:
#         State  Participation Rate  Mean EBRW  Mean Math  Mean Total
# 0     Alabama                0.07        576        551        1127
# 1      Alaska                0.37        555        543        1098
# 2     Arizona                0.29        571        568        1139
# 3    Arkansas                0.04        590        567        1157
# 4  California                0.67        527        522        1049

# %%
#rename columns > change to lowercase with underscores
#trim white/trailing spaces in 'state' column

sat_2020.columns = sat_2020.columns.str.lower()
act_2020.columns = act_2020.columns.str.lower()

sat_2020.rename(columns={
    'state' : 'state',
    'participation rate' : 'participation_sat_2020',
    'mean ebrw' : 'ebrw_sat_2020',
    'mean math' : 'math_sat_2020',
    'mean total' : 'total_sat_2020'
}, inplace = True)

act_2020.rename(columns={
    'state' : 'state',
    'participation' : 'participation_act_2020',
    'composite score' : 'composite_act_2020',
},inplace = True)

act_2020['state'] = act_2020['state'].str.strip()
sat_2020['state'] = sat_2020['state'].str.strip()

#verify that the column names have been changed correctly
sat_2020.columns
#act_2020.columns
# Out:
# Index(['state', 'participation_sat_2020', 'ebrw_sat_2020', 'math_sat_2020',
#        'total_sat_2020'],
#       dtype='object')

# %%
#check for duplicates

dup_sat_2020 = len(sat_2020) - len(sat_2020.drop_duplicates())
dup_act_2020 = len(act_2020) - len(act_2020.drop_duplicates())

print (f'There are {dup_sat_2020} duplicate(s) in sat_2020.')
print(f'There are {dup_act_2020} duplicate(s) in act_2020.')
# Out:
# There are 0 duplicate(s) in sat_2020.
# There are 0 duplicate(s) in act_2020.

# %%
# merge 2020 datasets on 'state' key.
merged_2020 = pd.merge(sat_2020,act_2020,on='state')
merged_2020
# Out:
#                    state  participation_sat_2020  ebrw_sat_2020  \
# 0                Alabama                    0.07            576
# 1                 Alaska                    0.37            555
# 2                Arizona                    0.29            571
# 3               Arkansas                    0.04            590
# 4             California                    0.67            527
# 5               Colorado                    1.00            511
# 6            Connecticut                    1.00            527
# 7               Delaware                    1.00            497
# 8   District of Columbia                    1.00            498
# 9                Florida                    1.00            512
# 10               Georgia                    0.68            537
# 11                Hawaii                    0.51            549
# 12                 Idaho                    1.00            500
# 13              Illinois                    0.98            504
# ...

# %% [markdown]
# ## <span style='color:steelblue'> 2021 Datasets: Import & Cleaning </span>

# %%
sat_2021 = pd.read_csv("../data/sat_2021.csv", encoding='latin1')
act_2021 = pd.read_csv("../data/act_2021.csv")

# %%
#print first 5 rows of sat_2021
sat_2021.head()
# Out:
#         State Participation Rate   EBRW   Math   Total
# 0     Alabama                 3%  591.0  568.0  1159.0
# 1      Alaska                23%  567.0  553.0  1119.0
# 2     Arizona                11%  592.0  589.0  1181.0
# 3    Arkansas                 2%  610.0  584.0  1194.0
# 4  California                24%  527.0  530.0  1057.0

# %%
#print first 5 rows act_2021 
act_2021.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.7
# 1      Alaska           16%       20.6
# 2     Arizona           35%       19.8
# 3    Arkansas           99%       19.0
# 4  California            5%       26.1

# %%
#find out the index of the rows to drop
print('sat_2021: \n')
print(sat_2021.loc[(sat_2021['State'] == 'Puerto Rico') | (sat_2021['State'] == 'Virgin Islands, US')].head())
print('\n')
print('act_2021: \n')
print(act_2021.loc[(act_2021['State'] == 'National')].head())
# Out:
# sat_2021:
#
#                  State Participation Rate   EBRW   Math  Total
# 39         Puerto Rico       not provided  511.0  483.0  994.0
# 48  Virgin Islands, US       not provided  484.0  435.0  920.0
#
#
# act_2021:
#
#        State Participation  Composite
# 51  National           35%       20.3

# %%
#remove rows 39 (Puerto Rico) and 48 (Virgin Islands) rows from sat_2021
#remove row 51 (National) from act_2021

sat_2021 = sat_2021.drop(labels=[39,48],axis=0)
act_2021 = act_2021.drop(labels=[51],axis=0)

# %%
#verify that no. of rows for both sat_2021 and act_2021 are now the same. 
#However, the participation rate value for both datasets are of object datatype.
sat_2021.info()
#act_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   EBRW                51 non-null     float64
#  3   Math                51 non-null     float64
#  4   Total               51 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 2.4+ KB

# %%
#convert participation rate (string) to float datatype using function str_to_float

sat_2021['Participation Rate'] = sat_2021['Participation Rate'].astype(str).apply(str_to_float)
act_2021['Participation'] = act_2021['Participation'].astype(str).apply(str_to_float)

# %%
#verify that the participation rate values are converted into the right float format
sat_2021.head()
#act_2021.head()
# Out:
#         State  Participation Rate   EBRW   Math   Total
# 0     Alabama                0.03  591.0  568.0  1159.0
# 1      Alaska                0.23  567.0  553.0  1119.0
# 2     Arizona                0.11  592.0  589.0  1181.0
# 3    Arkansas                0.02  610.0  584.0  1194.0
# 4  California                0.24  527.0  530.0  1057.0

# %%
#rename columns > change to lowercase with underscores
#trim white/trailing spaces in 'state' column

sat_2021.columns = sat_2021.columns.str.lower()
act_2021.columns = act_2021.columns.str.lower()

sat_2021.rename(columns={
    'state' : 'state',
    'participation rate' : 'participation_sat_2021',
    'ebrw' : 'ebrw_sat_2021',
    'math' : 'math_sat_2021',
    'total' : 'total_sat_2021'
}, inplace = True)

act_2021.rename(columns={
    'state' : 'state',
    'participation' : 'participation_act_2021',
    'composite' : 'composite_act_2021',
},inplace = True)

act_2021['state'] = act_2021['state'].str.strip()
sat_2021['state'] = sat_2021['state'].str.strip()

# %%
#verify that the column names have been changed correctly
sat_2021.columns
#act_2021.columns
# Out:
# Index(['state', 'participation_sat_2021', 'ebrw_sat_2021', 'math_sat_2021',
#        'total_sat_2021'],
#       dtype='object')

# %%
#check for duplicates

dup_sat_2021 = len(sat_2021) - len(sat_2021.drop_duplicates())
dup_act_2021 = len(act_2021) - len(act_2021.drop_duplicates())

print (f'There are {dup_sat_2021} duplicate(s) in sat_2021.')
print(f'There are {dup_act_2021} duplicate(s) in act_2021.')
# Out:
# There are 0 duplicate(s) in sat_2021.
# There are 0 duplicate(s) in act_2021.

# %%
# merge 2021 datasets on 'state' key.
merged_2021 = pd.merge(sat_2021,act_2021,on='state')

# %%
# merge all three dataframes: merged_2019, merged_2020 and merged_2021
data = pd.merge(pd.merge(merged_2019,merged_2020,on='state'),merged_2021,on='state')

# %%
data.to_csv('data.csv',index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|string|SAT/ACT|This is a region in the USA|
# |year|int|SAT/ACT|Year of test taken|
# |participation_sat|int|SAT|Percentage of students who sat for the SAT exam|
# |ebrw_sat|int|SAT|Average score for SAT Evidence-Based Reading and Writing section|
# |math_sat|int|SAT|Average score for SAT Math section|
# |total_sat|int|SAT|Average SAT total score|
# |participation_act|int|ACT|Percentage of students who sat for the ACT exam|
# |composite_act|int|ACT|Average ACT composite score|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### <span style='color:blue'> Questions relevant to problem statement: </span>
#
# <ul style='color:blue'>
#
# * How are ACT and SAT participation rates and aggregated scores related to one another?
# * Which states have the highest and lowest participation rates for the 2019, 2020 or 2021 ACT and SAT?
# * Which states have the highest and lowest mean total/composite scores for the 2019, 2020, or 2021 ACT and SAT?
# * Which states managed to maintain the same ACT/SAT participation rates from 2019 to 2021?
# * Which states had the largest decline in ACT/SAT participation rates from 2019 to 2021?
# * Which states had the largest decline in ACT/SAT mean total/composite scores from 2019 to 2021?
# * Were there any states that had improvements in ACT/SAT participation rates or aggregated scores from 2019 to 2021?
#
# </ul>

# %%
summary = data.describe()
summary.transpose()
# Out:
#                         count         mean        std     min       25%  \
# participation_sat_2019   51.0     0.490588   0.387476    0.02     0.055
# ebrw_sat_2019            51.0   560.803922  46.248035  483.00   527.500
# math_sat_2019            51.0   552.196078  51.290553  460.00   511.500
# total_sat_2019           51.0  1113.078431  97.197910  943.00  1038.000
# participation_act_2019   51.0     0.586667   0.345159    0.06     0.245
# composite_act_2019       51.0    21.464706   2.194523   17.90    19.800
# participation_sat_2020   51.0     0.487059   0.389262    0.02     0.045
# ebrw_sat_2020            51.0   554.901961  42.780488  480.00   523.000
# math_sat_2020            51.0   545.549020  46.898321  456.00   505.000
# total_sat_2020           51.0  1100.352941  89.244344  936.00  1027.500
# participation_act_2020   51.0     0.569020   0.356428    0.05     0.215
# composite_act_2020       51.0    21.505882   2.398450   17.90    19.550
# ...

# %%
sd = {values:my_std_dev(data[values]) for values in data if values != 'state'}
print(sd)
# Out:
# {'participation_sat_2019': 0.3836584048685726, 'ebrw_sat_2019': 45.792378682545134, 'math_sat_2019': 50.78521461840036, 'total_sat_2019': 96.24027185617864, 'participation_act_2019': 0.3417582373703047, 'composite_act_2019': 2.172901153595978, 'participation_sat_2020': 0.3854271585903205, 'ebrw_sat_2020': 42.358995573068626, 'math_sat_2020': 46.43625769213747, 'total_sat_2020': 88.36506796493464, 'participation_act_2020': 0.3529164479354506, 'composite_act_2020': 2.374819849902831, 'participation_sat_2021': 0.2866983164309961, 'ebrw_sat_2021': 41.694814022128334, 'math_sat_2021': 46.02574376163838, 'total_sat_2021': 86.66122775942233, 'participation_act_2021': 0.3658099459699665, 'composite_act_2021': 2.8819140655606708}

# %%
# SAT 2019 highest participation rates (Top 10)
data[['state','participation_sat_2019']].sort_values(['participation_sat_2019','state'],ascending=(False,True)).head(10)
# Out:
#             state  participation_sat_2019
# 5        Colorado                    1.00
# 6     Connecticut                    1.00
# 7        Delaware                    1.00
# 9         Florida                    1.00
# 12          Idaho                    1.00
# 13       Illinois                    1.00
# 22       Michigan                    1.00
# 39   Rhode Island                    1.00
# 19          Maine                    0.99
# 48  West Virginia                    0.99

# %%
# SAT 2020 highest participation rates (Top 10)
data[['state','participation_sat_2020']].sort_values(['participation_sat_2020','state'],ascending=(False,True)).head(10)
# Out:
#                    state  participation_sat_2020
# 5               Colorado                    1.00
# 6            Connecticut                    1.00
# 7               Delaware                    1.00
# 8   District of Columbia                    1.00
# 9                Florida                    1.00
# 12                 Idaho                    1.00
# 22              Michigan                    1.00
# 39          Rhode Island                    1.00
# 13              Illinois                    0.98
# 19                 Maine                    0.98

# %%
# SAT 2021 highest participation rates (Top 10)
data[['state','participation_sat_2021']].sort_values(['participation_sat_2021','state'],ascending=(False,True)).head(10)
# Out:
#                    state  participation_sat_2021
# 7               Delaware                    0.96
# 8   District of Columbia                    0.90
# 12                 Idaho                    0.90
# 9                Florida                    0.81
# 13              Illinois                    0.80
# 29         New Hampshire                    0.71
# 6            Connecticut                    0.69
# 22              Michigan                    0.68
# 39          Rhode Island                    0.68
# 43                 Texas                    0.59

# %%
# SAT 2019 lowest participation rates (Bottom 10)
data[['state','participation_sat_2019']].sort_values(['participation_sat_2019','state'],ascending=(True,True)).head(10)
# Out:
#            state  participation_sat_2019
# 34  North Dakota                    0.02
# 15          Iowa                    0.03
# 24   Mississippi                    0.03
# 27      Nebraska                    0.03
# 41  South Dakota                    0.03
# 49     Wisconsin                    0.03
# 50       Wyoming                    0.03
# 16        Kansas                    0.04
# 17      Kentucky                    0.04
# 23     Minnesota                    0.04

# %%
# SAT 2020 lowest participation rates (Bottom 10)
data[['state','participation_sat_2020']].sort_values(['participation_sat_2020','state'],ascending=(True,True)).head(10)
# Out:
#            state  participation_sat_2020
# 34  North Dakota                    0.02
# 50       Wyoming                    0.02
# 15          Iowa                    0.03
# 24   Mississippi                    0.03
# 27      Nebraska                    0.03
# 41  South Dakota                    0.03
# 44          Utah                    0.03
# 49     Wisconsin                    0.03
# 3       Arkansas                    0.04
# 16        Kansas                    0.04

# %%
# SAT 2021 lowest participation rates (Bottom 10)
data[['state','participation_sat_2021']].sort_values(['participation_sat_2021','state'],ascending=(True,True)).head(10)
# Out:
#            state  participation_sat_2021
# 24   Mississippi                    0.01
# 34  North Dakota                    0.01
# 41  South Dakota                    0.01
# 44          Utah                    0.01
# 49     Wisconsin                    0.01
# 3       Arkansas                    0.02
# 15          Iowa                    0.02
# 16        Kansas                    0.02
# 23     Minnesota                    0.02
# 25      Missouri                    0.02

# %%
# How many states maintained 100% SAT participation rates from 2019 to 2021? 
len(data[(data['participation_sat_2019']==1) & (data['participation_sat_2020']==1) & (data['participation_sat_2021']==1)])
# Out:
# 0

# %%
# How many states experienced year-on-year decline in SAT participation rates from 2019 to 2021?
len(data[(data['participation_sat_2019'] > data['participation_sat_2020']) & (data['participation_sat_2020'] > data['participation_sat_2021'])])
# Out:
# 19

# %%
# Which are the states? 
data[(data['participation_sat_2019'] > data['participation_sat_2020']) & (data['participation_sat_2020'] > data['participation_sat_2021'])]['state']
# Out:
# 1             Alaska
# 2            Arizona
# 3           Arkansas
# 10           Georgia
# 11            Hawaii
# 13          Illinois
# 14           Indiana
# 19             Maine
# 21     Massachusetts
# 28            Nevada
# 29     New Hampshire
# 33    North Carolina
# 36          Oklahoma
# 38      Pennsylvania
# 44              Utah
# 45           Vermont
# 46          Virginia
# 47        Washington
# 48     West Virginia
# Name: state, dtype: object

# %%
# How many states experienced year-on-year improvement in SAT participation rates from 2019 to 2021?
len(data[(data['participation_sat_2019'] < data['participation_sat_2020']) & (data['participation_sat_2020'] < data['participation_sat_2021'])])
# Out:
# 1

# %%
# Which are the states? 
data[(data['participation_sat_2019'] < data['participation_sat_2020']) & (data['participation_sat_2020'] < data['participation_sat_2021'])]['state']
# Out:
# 31    New Mexico
# Name: state, dtype: object

# %%
# created function to calculate change over time period
def percentage_change(col1,col2):
    return ((col2 - col1) / col1)

# %%
data['satp_change_2019_2021'] = percentage_change(data['participation_sat_2019'],data['participation_sat_2021'])

# %%
# 10 States that showed the largest decline in SAT participation rates from 2019 to 2021
data[['state','satp_change_2019_2021']].sort_values('satp_change_2019_2021',ascending=True).head(10)
# Out:
#            state  satp_change_2019_2021
# 28        Nevada              -0.800000
# 44          Utah              -0.750000
# 36      Oklahoma              -0.727273
# 19         Maine              -0.707071
# 41  South Dakota              -0.666667
# 37        Oregon              -0.666667
# 49     Wisconsin              -0.666667
# 24   Mississippi              -0.666667
# 3       Arkansas              -0.666667
# 2        Arizona              -0.645161

# %%
# States that had >50% participation rate in 2019 but experienced the largest decline in SAT participation rates from 2019 to 2021
data[(data['participation_sat_2019'] > 0.5)][['state','participation_sat_2019','participation_sat_2020','participation_sat_2021','satp_change_2019_2021']].sort_values('satp_change_2019_2021',ascending=True).head()
# Out:
#             state  participation_sat_2019  participation_sat_2020  \
# 19          Maine                    0.99                    0.98
# 37         Oregon                    0.51                    0.51
# 4      California                    0.63                    0.67
# 47     Washington                    0.70                    0.69
# 21  Massachusetts                    0.81                    0.80
#
#     participation_sat_2021  satp_change_2019_2021
# 19                    0.29              -0.707071
# 37                    0.17              -0.666667
# 4                     0.24              -0.619048
# 47                    0.27              -0.614286
# 21                    0.34              -0.580247

# %%
# States that showed improvements in SAT participation from 2019 to 2021
data.loc[data['satp_change_2019_2021'] > 0,['state','satp_change_2019_2021']].sort_values('satp_change_2019_2021',ascending=True)
# Out:
#          state  satp_change_2019_2021
# 31  New Mexico               0.666667

# %%
# SAT 2019 highest total score (Top 10)
data[['state','total_sat_2019']].sort_values(['total_sat_2019','state'],ascending=(False,True)).head(10)
# Out:
#            state  total_sat_2019
# 23     Minnesota            1284
# 49     Wisconsin            1283
# 41  South Dakota            1268
# 34  North Dakota            1263
# 27      Nebraska            1260
# 15          Iowa            1244
# 16        Kansas            1241
# 50       Wyoming            1238
# 24   Mississippi            1237
# 25      Missouri            1236

# %%
# SAT 2020 highest total score (Top 10)
data[['state','total_sat_2020']].sort_values(['total_sat_2020','state'],ascending=(False,True)).head(10)
# Out:
#            state  total_sat_2020
# 23     Minnesota            1257
# 49     Wisconsin            1243
# 16        Kansas            1237
# 34  North Dakota            1231
# 27      Nebraska            1229
# 15          Iowa            1220
# 50       Wyoming            1220
# 41  South Dakota            1218
# 25      Missouri            1212
# 17      Kentucky            1207

# %%
# SAT 2021 highest total score (Top 10)
data[['state','total_sat_2021']].sort_values(['total_sat_2021','state'],ascending=(False,True)).head(10)
# Out:
#            state  total_sat_2021
# 23     Minnesota          1263.0
# 34  North Dakota          1258.0
# 27      Nebraska          1246.0
# 15          Iowa          1243.0
# 44          Utah          1238.0
# 50       Wyoming          1233.0
# 26       Montana          1225.0
# 42     Tennessee          1220.0
# 16        Kansas          1219.0
# 25      Missouri          1219.0

# %%
# SAT 2019 lowest total score (Bottom 10)
data[['state','total_sat_2019']].sort_values(['total_sat_2019','state'],ascending=(True,True)).head(10)
# Out:
#                    state  total_sat_2019
# 48         West Virginia             943
# 36              Oklahoma             963
# 8   District of Columbia             975
# 7               Delaware             985
# 12                 Idaho             993
# 39          Rhode Island             995
# 9                Florida             999
# 22              Michigan            1003
# 13              Illinois            1013
# 19                 Maine            1013

# %%
# SAT 2020 lowest total score (Bottom 10)
data[['state','total_sat_2020']].sort_values(['total_sat_2020','state'],ascending=(True,True)).head(10)
# Out:
#                    state  total_sat_2020
# 48         West Virginia             936
# 36              Oklahoma             971
# 7               Delaware             978
# 8   District of Columbia             979
# 12                 Idaho             984
# 39          Rhode Island             990
# 9                Florida             992
# 19                 Maine             995
# 22              Michigan             998
# 13              Illinois            1007

# %%
# SAT 2021 lowest total score (Bottom 10)
data[['state','total_sat_2021']].sort_values(['total_sat_2021','state'],ascending=(True,True)).head(10)
# Out:
#                    state  total_sat_2021
# 7               Delaware           984.0
# 12                 Idaho           985.0
# 8   District of Columbia           987.0
# 9                Florida           993.0
# 31            New Mexico           996.0
# 43                 Texas          1003.0
# 13              Illinois          1007.0
# 48         West Virginia          1007.0
# 39          Rhode Island          1011.0
# 22              Michigan          1031.0

# %%
# How many states maintained the same SAT total scores from 2019 to 2021? 
len(data[(data['total_sat_2019']==data['total_sat_2020']) & (data['total_sat_2020']==data['total_sat_2021'])])
# Out:
# 0

# %%
data['satscore_change_2019_2021'] = percentage_change(data['total_sat_2019'],data['total_sat_2021'])

# %%
# 10 States that showed the largest decline in SAT total scores from 2019 to 2021
data[['state','satscore_change_2019_2021']].sort_values('satscore_change_2019_2021',ascending=True).head(10)
# Out:
#            state  satscore_change_2019_2021
# 31    New Mexico                  -0.071761
# 49     Wisconsin                  -0.053001
# 35          Ohio                  -0.044667
# 41  South Dakota                  -0.041798
# 24   Mississippi                  -0.028294
# 17      Kentucky                  -0.020292
# 43         Texas                  -0.018591
# 16        Kansas                  -0.017728
# 23     Minnesota                  -0.016355
# 25      Missouri                  -0.013754

# %%
# States that had above average SAT total scores in 2019 (i.e. > 1113) but experienced the largest decline in SAT participation rates from 2019 to 2021
data[(data['total_sat_2019'] > 1113)][['state','total_sat_2019','total_sat_2020','total_sat_2021','satscore_change_2019_2021']].sort_values('satscore_change_2019_2021',ascending=True).head()
# Out:
#            state  total_sat_2019  total_sat_2020  total_sat_2021  \
# 49     Wisconsin            1283            1243          1215.0
# 41  South Dakota            1268            1218          1215.0
# 24   Mississippi            1237            1203          1202.0
# 17      Kentucky            1232            1207          1207.0
# 16        Kansas            1241            1237          1219.0
#
#     satscore_change_2019_2021
# 49                  -0.053001
# 41                  -0.041798
# 24                  -0.028294
# 17                  -0.020292
# 16                  -0.017728

# %%
# How many states experienced year-on-year decline in SAT total scores from 2019 to 2021?
len(data[(data['total_sat_2019'] > data['total_sat_2020']) & (data['total_sat_2020'] > data['total_sat_2021'])])
# Out:
# 9

# %%
#Which are the states?
data[(data['total_sat_2019'] > data['total_sat_2020']) & (data['total_sat_2020'] > data['total_sat_2021'])]['state']
# Out:
# 16          Kansas
# 24     Mississippi
# 31      New Mexico
# 32        New York
# 35            Ohio
# 41    South Dakota
# 43           Texas
# 47      Washington
# 49       Wisconsin
# Name: state, dtype: object

# %%
# How many states experienced year-on-year improvement in SAT total scores from 2019 to 2021?
len(data[(data['total_sat_2019'] < data['total_sat_2020']) & (data['total_sat_2020'] < data['total_sat_2021'])])
# Out:
# 5

# %%
# Which are the states?
data[(data['total_sat_2019'] < data['total_sat_2020']) & (data['total_sat_2020'] < data['total_sat_2021'])]['state']
# Out:
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 8     District of Columbia
# 36                Oklahoma
# Name: state, dtype: object

# %% [markdown]
# ### ACT

# %%
#to check no of states that achieved 100% ACT participation rate in a given year
len(data[data.participation_act_2019 == 1])
# to check for year 2020 and 2021 too.
# Out:
# 15

# %%
# ACT 2019 highest participation rates (Top 15)
data[['state','participation_act_2019']].sort_values(['participation_act_2019','state'],ascending=(False,True)).head(15)
# Out:
#              state  participation_act_2019
# 0          Alabama                     1.0
# 3         Arkansas                     1.0
# 17        Kentucky                     1.0
# 18       Louisiana                     1.0
# 24     Mississippi                     1.0
# 26         Montana                     1.0
# 27        Nebraska                     1.0
# 28          Nevada                     1.0
# 33  North Carolina                     1.0
# 35            Ohio                     1.0
# 36        Oklahoma                     1.0
# 42       Tennessee                     1.0
# 44            Utah                     1.0
# 49       Wisconsin                     1.0
# 50         Wyoming                     1.0

# %%
# ACT 2020 highest participation rates (Top 15)
data[['state','participation_act_2020']].sort_values(['participation_act_2020','state'],ascending=(False,True)).head(15)
# Out:
#              state  participation_act_2020
# 0          Alabama                     1.0
# 3         Arkansas                     1.0
# 17        Kentucky                     1.0
# 18       Louisiana                     1.0
# 24     Mississippi                     1.0
# 26         Montana                     1.0
# 27        Nebraska                     1.0
# 28          Nevada                     1.0
# 33  North Carolina                     1.0
# 35            Ohio                     1.0
# 36        Oklahoma                     1.0
# 42       Tennessee                     1.0
# 44            Utah                     1.0
# 49       Wisconsin                     1.0
# 50         Wyoming                     1.0

# %%
# ACT 2021 highest participation rates (Top 15)
data[['state','participation_act_2021']].sort_values(['participation_act_2021','state'],ascending=(False,True)).head(15)
# Out:
#              state  participation_act_2021
# 0          Alabama                    1.00
# 17        Kentucky                    1.00
# 24     Mississippi                    1.00
# 28          Nevada                    1.00
# 34    North Dakota                    1.00
# 42       Tennessee                    1.00
# 3         Arkansas                    0.99
# 18       Louisiana                    0.98
# 49       Wisconsin                    0.96
# 33  North Carolina                    0.92
# 50         Wyoming                    0.91
# 27        Nebraska                    0.86
# 44            Utah                    0.86
# 35            Ohio                    0.85
# 16          Kansas                    0.79

# %%
# ACT 2019 lowest participation rates (Bottom 10)
data[['state','participation_act_2019']].sort_values(['participation_act_2019','state'],ascending=(True,True)).head(10)
# Out:
#             state  participation_act_2019
# 19          Maine                    0.06
# 39   Rhode Island                    0.12
# 7        Delaware                    0.13
# 29  New Hampshire                    0.14
# 38   Pennsylvania                    0.17
# 22       Michigan                    0.19
# 45        Vermont                    0.20
# 21  Massachusetts                    0.21
# 46       Virginia                    0.21
# 6     Connecticut                    0.22

# %%
# ACT 2020 lowest participation rates (Bottom 10)
data[['state','participation_act_2020']].sort_values(['participation_act_2020','state'],ascending=(True,True)).head(10)
# Out:
#             state  participation_act_2020
# 19          Maine                    0.05
# 7        Delaware                    0.11
# 39   Rhode Island                    0.11
# 29  New Hampshire                    0.12
# 38   Pennsylvania                    0.15
# 22       Michigan                    0.17
# 21  Massachusetts                    0.18
# 4      California                    0.19
# 6     Connecticut                    0.19
# 20       Maryland                    0.19

# %%
# ACT 2021 lowest participation rates (Bottom 10)
data[['state','participation_act_2021']].sort_values(['participation_act_2021','state'],ascending=(True,True)).head(10)
# Out:
#             state  participation_act_2021
# 19          Maine                    0.02
# 29  New Hampshire                    0.04
# 39   Rhode Island                    0.04
# 45        Vermont                    0.04
# 4      California                    0.05
# 7        Delaware                    0.05
# 21  Massachusetts                    0.07
# 38   Pennsylvania                    0.07
# 47     Washington                    0.07
# 20       Maryland                    0.08

# %%
# How many states maintained 100% ACT participation rates from 2019 to 2021? 
len(data[(data['participation_act_2019']==1) & (data['participation_act_2020']==1) & (data['participation_act_2021']==1)])
# Out:
# 5

# %%
# What are the states? 
data[(data['participation_act_2019']==1) & (data['participation_act_2020']==1) & (data['participation_act_2021']==1)]['state']
# Out:
# 0         Alabama
# 17       Kentucky
# 24    Mississippi
# 28         Nevada
# 42      Tennessee
# Name: state, dtype: object

# %%
data['actp_change_2019_2021'] = percentage_change(data['participation_act_2019'],data['participation_act_2021'])

# %%
data.loc[data['state'] == 'New Mexico']
# Out:
#          state  participation_sat_2019  ebrw_sat_2019  math_sat_2019  \
# 31  New Mexico                    0.18            543            530
#
#     total_sat_2019  participation_act_2019  composite_act_2019  \
# 31            1073                    0.63                19.3
#
#     participation_sat_2020  ebrw_sat_2020  math_sat_2020  ...  \
# 31                    0.19            533            522  ...
#
#     composite_act_2020  participation_sat_2021  ebrw_sat_2021  math_sat_2021  \
# 31                19.3                     0.3          508.0          488.0
#
#     total_sat_2021  participation_act_2021  composite_act_2021  \
# 31           996.0                    0.23                20.7
#
#     satp_change_2019_2021  satscore_change_2019_2021  actp_change_2019_2021
# 31               0.666667                  -0.071761              -0.634921
#
# [1 rows x 22 columns]

# %%
# 10 States that showed the largest decline in ACT participation rates from 2019 to 2021
data[['state','actp_change_2019_2021']].sort_values('actp_change_2019_2021',ascending=True).head(10)
# Out:
#             state  actp_change_2019_2021
# 45        Vermont              -0.800000
# 4      California              -0.782609
# 29  New Hampshire              -0.714286
# 20       Maryland              -0.714286
# 47     Washington              -0.708333
# 19          Maine              -0.666667
# 39   Rhode Island              -0.666667
# 21  Massachusetts              -0.666667
# 31     New Mexico              -0.634921
# 7        Delaware              -0.615385

# %%
# 10 States that showed the largest decline in ACT participation rates from 2019 to 2021
data[['state','actp_change_2019_2021']].sort_values('actp_change_2019_2021',ascending=True).head(10)
# Out:
#             state  actp_change_2019_2021
# 45        Vermont              -0.800000
# 4      California              -0.782609
# 29  New Hampshire              -0.714286
# 20       Maryland              -0.714286
# 47     Washington              -0.708333
# 19          Maine              -0.666667
# 39   Rhode Island              -0.666667
# 21  Massachusetts              -0.666667
# 31     New Mexico              -0.634921
# 7        Delaware              -0.615385

# %%
# States that had > mean participation rate in ACT 2019 but experienced the largest decline from 2019 to 2021
data[(data['participation_act_2019'] > 0.58)][['state','participation_act_2019','participation_act_2020','participation_act_2021','actp_change_2019_2021']].sort_values('actp_change_2019_2021',ascending=True).head()
# Out:
#              state  participation_act_2019  participation_act_2020  \
# 31      New Mexico                    0.63                    0.56
# 2          Arizona                    0.73                    0.71
# 36        Oklahoma                    1.00                    1.00
# 23       Minnesota                    0.95                    0.92
# 40  South Carolina                    0.78                    0.76
#
#     participation_act_2021  actp_change_2019_2021
# 31                    0.23              -0.634921
# 2                     0.35              -0.520548
# 36                    0.58              -0.420000
# 23                    0.60              -0.368421
# 40                    0.50              -0.358974

# %%
# How many states experienced year-on-year improvement in ACT participation rates from 2019 to 2021?
len(data[(data['participation_act_2019'] < data['participation_act_2020']) & (data['participation_act_2020'] < data['participation_act_2021'])])
# Out:
# 0

# %%
# 10 States that showed improvements in ACT participation from 2019 to 2021
data.loc[data['actp_change_2019_2021'] > 0,['state','actp_change_2019_2021']].sort_values('actp_change_2019_2021',ascending=True)
# Out:
#            state  actp_change_2019_2021
# 34  North Dakota               0.041667
# 16        Kansas               0.097222

# %%
# ACT 2019 highest composite score (Top 10)
data[['state','composite_act_2019']].sort_values(['composite_act_2019','state'],ascending=(False,True)).head(10)
# Out:
#             state  composite_act_2019
# 6     Connecticut                25.5
# 21  Massachusetts                25.5
# 29  New Hampshire                25.0
# 39   Rhode Island                24.7
# 32       New York                24.5
# 22       Michigan                24.4
# 13       Illinois                24.3
# 19          Maine                24.3
# 30     New Jersey                24.2
# 7        Delaware                24.1

# %%
# ACT 2020 highest composite score (Top 10)
data[['state','composite_act_2020']].sort_values(['composite_act_2020','state'],ascending=(False,True)).head(10)
# Out:
#             state  composite_act_2020
# 21  Massachusetts                26.0
# 6     Connecticut                25.9
# 29  New Hampshire                25.7
# 19          Maine                24.9
# 32       New York                24.9
# 39   Rhode Island                24.8
# 13       Illinois                24.7
# 22       Michigan                24.6
# 30     New Jersey                24.4
# 46       Virginia                24.4

# %%
# ACT 2021 highest composite score (Top 10)
data[['state','composite_act_2021']].sort_values(['composite_act_2021','state'],ascending=(False,True)).head(10)
# Out:
#                    state  composite_act_2021
# 21         Massachusetts                27.6
# 6            Connecticut                27.2
# 29         New Hampshire                26.6
# 32              New York                26.3
# 4             California                26.1
# 39          Rhode Island                25.8
# 7               Delaware                25.7
# 8   District of Columbia                25.6
# 19                 Maine                25.6
# 20              Maryland                25.5

# %%
# ACT 2019 lowest composite score (Bottom 10)
data[['state','composite_act_2019']].sort_values(['composite_act_2019','state'],ascending=(True,True)).head(10)
# Out:
#              state  composite_act_2019
# 28          Nevada                17.9
# 24     Mississippi                18.4
# 18       Louisiana                18.8
# 40  South Carolina                18.8
# 0          Alabama                18.9
# 36        Oklahoma                18.9
# 2          Arizona                19.0
# 11          Hawaii                19.0
# 33  North Carolina                19.0
# 3         Arkansas                19.3

# %%
# ACT 2020 lowest composite (Bottom 10)
data[['state','composite_act_2020']].sort_values(['composite_act_2020','state'],ascending=(True,True)).head(10)
# Out:
#              state  composite_act_2020
# 28          Nevada                17.9
# 24     Mississippi                18.2
# 40  South Carolina                18.4
# 11          Hawaii                18.5
# 18       Louisiana                18.7
# 36        Oklahoma                18.7
# 0          Alabama                18.8
# 33  North Carolina                18.8
# 3         Arkansas                19.0
# 2          Arizona                19.1

# %%
# ACT 2021 lowest composite score (Bottom 10)
data[['state','composite_act_2021']].sort_values(['composite_act_2021','state'],ascending=(True,True)).head(10)
# Out:
#              state  composite_act_2021
# 28          Nevada                17.8
# 24     Mississippi                18.1
# 11          Hawaii                18.2
# 18       Louisiana                18.4
# 40  South Carolina                18.6
# 0          Alabama                18.7
# 33  North Carolina                18.9
# 3         Arkansas                19.0
# 42       Tennessee                19.1
# 17        Kentucky                19.2

# %%
# How many states maintained the same ACT composite scores from 2019 to 2021? 
len(data[(data['composite_act_2019']==data['composite_act_2020']) & (data['composite_act_2020']==data['composite_act_2021'])])
# Out:
# 0

# %%
# How many states experienced a year-on-year decline in ACT composite scores? 
len(data[(data['composite_act_2019']>data['composite_act_2020']) & (data['composite_act_2020']>data['composite_act_2021'])])
# Out:
# 13

# %%
# Name the states
data[(data['composite_act_2019']>data['composite_act_2020']) & (data['composite_act_2020']>data['composite_act_2021'])]['state']
# Out:
# 0         Alabama
# 5        Colorado
# 11         Hawaii
# 16         Kansas
# 17       Kentucky
# 18      Louisiana
# 24    Mississippi
# 25       Missouri
# 35           Ohio
# 37         Oregon
# 42      Tennessee
# 43          Texas
# 49      Wisconsin
# Name: state, dtype: object

# %%
data['actscore_change_2019_2021'] = percentage_change(data['composite_act_2019'],data['composite_act_2021'])

# %%
# 10 States that showed the largest decline in ACT scores from 2019 to 2021
data[['state','actscore_change_2019_2021']].sort_values('actscore_change_2019_2021',ascending=True).head(10)
# Out:
#           state  actscore_change_2019_2021
# 16       Kansas                  -0.061321
# 11       Hawaii                  -0.042105
# 17     Kentucky                  -0.030303
# 37       Oregon                  -0.023697
# 18    Louisiana                  -0.021277
# 35         Ohio                  -0.020000
# 43        Texas                  -0.019512
# 24  Mississippi                  -0.016304
# 3      Arkansas                  -0.015544
# 42    Tennessee                  -0.015464

# %%
# States that had above average ACT composite score in 2019 (i.e. > 21.4) but experienced the largest decline from 2019 to 2021
data[(data['composite_act_2019'] > 21.4)][['state','composite_act_2019','composite_act_2020','composite_act_2021','actscore_change_2019_2021']].sort_values('actscore_change_2019_2021',ascending=True).head()
# Out:
#            state  composite_act_2019  composite_act_2020  composite_act_2021  \
# 5       Colorado                23.8                23.7                23.6
# 15          Iowa                21.6                21.1                21.5
# 41  South Dakota                21.6                21.7                21.6
# 12         Idaho                22.5                22.7                23.0
# 45       Vermont                24.1                23.3                24.7
#
#     actscore_change_2019_2021
# 5                   -0.008403
# 15                  -0.004630
# 41                   0.000000
# 12                   0.022222
# 45                   0.024896

# %%
# How many states experienced year-on-year improvement in ACT participation rates from 2019 to 2021?
len(data[(data['composite_act_2019'] < data['composite_act_2020']) & (data['composite_act_2020'] < data['composite_act_2021'])])
# Out:
# 20

# %%
# Which are the states?
data[(data['composite_act_2019'] < data['composite_act_2020']) & (data['composite_act_2020'] < data['composite_act_2021'])]['state']
# Out:
# 2           Arizona
# 4        California
# 6       Connecticut
# 7          Delaware
# 10          Georgia
# 12            Idaho
# 13         Illinois
# 14          Indiana
# 19            Maine
# 20         Maryland
# 21    Massachusetts
# 22         Michigan
# 26          Montana
# 29    New Hampshire
# 30       New Jersey
# 32         New York
# 38     Pennsylvania
# 39     Rhode Island
# 46         Virginia
# 47       Washington
# Name: state, dtype: object

# %% [markdown]
# <span style='color:blue'> **Key Findings**</span>
#
# <ul style='color:blue'>
#
# * The mean/median of SAT/ACT participation rates and aggregated scores certainly decreased across board over the 3 year period.
#
# **Participation Rates**
#
# *ACT*
# * There are 5 states that maintained 100% participation rate in ACT from 2019 to 2021 i.e. Alabama, Kentucky, Mississippi, Nevada, Tennessee. However, none of the states demonstrated year-on-year improvement in participation rates from 2019 to 2021.
#
# * There are 6 states that had above average participation rate in ACT in 2019, but experienced significant decline in participation rate from 2019 to 2021 i.e. New Mexico (-0.63), Arizona (-0.52), Oklahoma (-0.42), Minnestoa (-0.36), South Carolina (-0.35)
#
# *SAT*
# * None of the states maintained 100% participation rate in SAT from 2019 to 2021. Interestingly, one state i.e. New Mexico saw year-on-year improvement in participation rates from 2019 to 2021.
#
# * There are 5 states that had above average participation rate in SAT in 2019, but experienced significant decline in participation rate from 2019 to 2021 i.e. Maine (-0.70), Oregon (-0.66), California (-0.61), Washington (-0.61), Massachusetts (-0.58).
#
# **Aggregated Scores**
#
# *ACT*
# * None of the states maintained the same ACT composite score from 2019 to 2021.
# * None of the states experienced a year-on-year improvement in ACT composite score from 2019 to 2021.
# * 13 states experienced year-on-year decline in ACT composite scores from 2019 to 2021.
# * There are 5 states that had above average ACT composite score in 2019, but experienced a decline in composite score from 2019 to 2021. However, the percentage difference is small - between 0.4% to 0.8%.
#
# *SAT*
# * None of the states maintained the same SAT total score from 2019 to 2021.
# * Interestingly, 5 states experienced a year-on-year improvement in SAT total scores from 2019 to 2021 i.e. Alaska, Arizona, Arkansas, District of Columbia, Oklahoma.
# * 9 states experienced year-on-year decline in SAT total scores from 2019 to 2021.
# * There are 5 states that had above average SAT total score in 2019, but experienced significant decline in composite score from 2019 to 2021. The percengate difference is between 1% to 8%.
#
# </ul>

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#to drop additional columns that were added earlier to calculate percentage changes over time. 

df = data.drop(['satp_change_2019_2021','satscore_change_2019_2021','actp_change_2019_2021','actscore_change_2019_2021'],axis=1)

# %%
df.corr()
# Out:
#                         participation_sat_2019  ebrw_sat_2019  math_sat_2019  \
# participation_sat_2019                1.000000      -0.873453      -0.845841
# ebrw_sat_2019                        -0.873453       1.000000       0.986026
# math_sat_2019                        -0.845841       0.986026       1.000000
# total_sat_2019                       -0.861786       0.996134       0.996825
# participation_act_2019               -0.865435       0.688592       0.643101
# composite_act_2019                    0.724619      -0.460065      -0.390668
# participation_sat_2020                0.998541      -0.874517      -0.846111
# ebrw_sat_2020                        -0.868604       0.992665       0.977562
# math_sat_2020                        -0.849700       0.979499       0.993311
# total_sat_2020                       -0.862162       0.989842       0.989806
# participation_act_2020               -0.873722       0.700845       0.658396
# ...

# %%
df.describe().transpose()
# Out:
#                         count         mean        std     min       25%  \
# participation_sat_2019   51.0     0.490588   0.387476    0.02     0.055
# ebrw_sat_2019            51.0   560.803922  46.248035  483.00   527.500
# math_sat_2019            51.0   552.196078  51.290553  460.00   511.500
# total_sat_2019           51.0  1113.078431  97.197910  943.00  1038.000
# participation_act_2019   51.0     0.586667   0.345159    0.06     0.245
# composite_act_2019       51.0    21.464706   2.194523   17.90    19.800
# participation_sat_2020   51.0     0.487059   0.389262    0.02     0.045
# ebrw_sat_2020            51.0   554.901961  42.780488  480.00   523.000
# math_sat_2020            51.0   545.549020  46.898321  456.00   505.000
# total_sat_2020           51.0  1100.352941  89.244344  936.00  1027.500
# participation_act_2020   51.0     0.569020   0.356428    0.05     0.215
# composite_act_2020       51.0    21.505882   2.398450   17.90    19.550
# ...

# %%
#correlation heatmap

fig,ax = plt.subplots(figsize=(20,10))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
sns.heatmap(df.corr(),annot=True,cmap='Blues',linewidths=2,square=True,mask=mask)
ax.set_title('Correlation Heatmap of ACT & SAT Data',fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of ACT & SAT Data')

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * There is strong negative correlation between participation rates in ACT and participation rates in SAT across all three years.
# * There is moderate negative correlation (~-0.42) between ACT composite scores and SAT total scores across all three years.
# * There is strong negative correlation between SAT participation rates and SAT total scores across all three years.
# * There is strong negative correlation between ACT participation rates and ACT composite scores across all three years.
#
# </ul>

# %%
# created function to build histplot subplots 

def subplot_histplot(dataframe,columns,titles,xlabels):

    fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(20,10))
    ax = ax.ravel() 
    
    plt.subplots_adjust(hspace = 0.5)
    
    index = 0
    
    for i, column in enumerate(columns): 
        sns.histplot(dataframe[column],bins=10,ax=ax[index],color='purple',kde=True)
        ax[index].set_title(titles[i], fontsize = 15)
        ax[index].set_xlabel(xlabels[i])
        
        index+=1

# %%
#generated histplot subplots for participation rates for SAT and ACT tests

subplot_histplot(df,
                   columns=['participation_sat_2019', 'participation_sat_2020','participation_sat_2021', 
                           'participation_act_2019', 'participation_act_2020', 'participation_act_2021'],
                   
                   titles=['SAT 2019 Participation', 'SAT 2020 Participation', 'SAT 2021 Participation',
                                   'ACT 2019 Participation', 'ACT 2020 Participation', 'ACT 2021 Participation'], 
                   
                   xlabels=['participation rate', 'participation rate', 'participation rate', 'participation rate', 'participation rate', 'participation rate'])

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * The distributions of SAT participation rates are quite similiar in 2019 and 2020. However, in 2021, there were more states that had lower SAT participation rates.
# * The distributions of ACT participation rates are consistent in 2019 and 2020, with a higher number of states having high participation rates. However, this changed in 2021 as the distribution of ACT participation rates tends towards a positive skew, with a higher number of states having low participation rates.
#
# </ul>

# %%
#generated histplot subplots for participation rates for SAT and ACT tests

subplot_histplot(data,
                   columns=['total_sat_2019', 'total_sat_2020','total_sat_2021', 
                           'composite_act_2019', 'composite_act_2020', 'composite_act_2021'],
                   
                   titles=['SAT 2019 Total Score', 'SAT 2020 Total Score', 'SAT 2021 Total Score',
                                   'ACT 2019 Composite Score', 'ACT 2020 Composite Score', 'ACT 2021 Composite Score'], 
                   
                   xlabels=['total score', 'total score', 'total score', 'composite score', 'composite score', 'composite score'])

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * The distributions of SAT total scores are quite similiar in 2019 and 2020, tending towards normal distributions. However, in 2021, there were more states that had lower SAT total scores.
# * The ACT composite scores are consistently normally distributed from 2019 to 2021. However, in 2021, there were fewer states that had high ACT composite scores.
#
# </ul>

# %%
# boxplot subplots for SAT and ACT participation rates

act_sat = df[['participation_act_2019','participation_sat_2019', 'participation_act_2020','participation_sat_2020','participation_act_2021','participation_sat_2021']]

fig,ax = plt.subplots(figsize=(15,8))
box = ax.boxplot(act_sat,patch_artist=True,medianprops=dict(color='r'))
plt.xticks([1,2,3,4,5,6],['ACT 2019','SAT 2019','ACT 2020','SAT 2020','ACT 2021','SAT 2021'],fontsize=15)
plt.title('SAT/ACT Participation Rate', fontsize=20)

colors = ['lightblue', 'silver','lightblue', 'silver','lightblue', 'silver']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)   
    
plt.show()

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * All the boxplots are considerably long which suggests that there is a wide range of participation rates in ACT and SAT tests across all three years.
# * In 2019 and 2020, the median of ACT and SAT participation rates are at about the same level with a slight decrease from 2019 to 2020. However, the boxplots of ACT participation rates are comparatively higher than the boxplots of SAT participation rates.
# * In 2021, the median of ACT and SAT participation rates dropped and their interquartile ranges decreased. The boxplot of the SAT participation rate saw a significant decrease in the interquartile range.
#
# </ul>

# %%
#combined boxplots for SAT scores

sat_scores = df[['total_sat_2019','total_sat_2020','total_sat_2021']]
  
fig,ax = plt.subplots(figsize=(15,8))
box = ax.boxplot(sat_scores,patch_artist=True,
            boxprops=dict(facecolor='silver'),
            medianprops=dict(color='red'),
            )

plt.xticks([1,2,3],['2019','2020','2021'])
plt.title('SAT Total Scores', fontsize=20) 
    
plt.show()

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * The boxplots for SAT total scores became shorter year-on-year, which indicates  a decrease in the spread of data.
# * The median of SAT total scores had a slight increase from 2019 to 2021.
#
# </ul>

# %%
#combined boxplots for ACT scores

act_scores = df[['composite_act_2019','composite_act_2020','composite_act_2021']]
  
fig,ax = plt.subplots(figsize=(15,8))
box = ax.boxplot(sat_scores,patch_artist=True,
            boxprops=dict(facecolor='silver'),
            medianprops=dict(color='red'),
            )

plt.xticks([1,2,3],['2019','2020','2021'])
plt.title('ACT Composite Scores', fontsize=20) 
    
plt.show()

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * The boxplots for ACT composite scores became shorter year-on-year, which indicates  a decrease in the spread of data.
# * The median of ACT composite scores had a slight increase from 2019 to 2021.
# * While the boxplot for 2019 is skewed to the right, it tends toward symmetry in 2021.
#
# </ul>

# %%
# defined a function to build scatterplot subplots 

def subplot_scatterplot(data,x,y,z,xlabel,ylabel):

    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20,5))
    ax = ax.ravel() 
    
    plt.subplots_adjust(hspace = 0.5)
    
    index = 0 
    
    for a1,b1,c1 in zip(x,y,z):
        
        sns.regplot(x=data[a1],y=data[b1],ax=ax[index])
        ax[index].set_xlabel(xlabel, fontsize=12)
        ax[index].set_ylabel(ylabel,fontsize=12)
        ax[index].set_title(c1, fontsize=20),
        ax[index].set_xlim((0,1)),
        ax[index].set_ylim((0,1))
        index += 1

# %%
subplot_scatterplot(data=data,
                    x=['participation_sat_2019','participation_sat_2020','participation_sat_2021'],
                    y=['participation_act_2019','participation_act_2020','participation_act_2021'],
                    z=[2019,2020,2021],
                    xlabel = 'SAT participation rate',
                    ylabel = 'ACT participation rate'
                   )

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * Negative linear relationship between ACT and SAT participation rates across all three years.
#
# </ul>

# %%
# scatterplots on ACT/SAT scores

subplot_scatterplot(data=data,
                    x=['total_sat_2019','total_sat_2020','total_sat_2021'],
                    y=['composite_act_2019','composite_act_2020','composite_act_2021'],
                    z=[2019,2020,2021],
                    xlabel='SAT total score',
                    ylabel='ACT composite score'
        
                   )

# %% [markdown]
# <span style='color:blue'> **Interpretation**</span>
# <ul style='color:blue'>
#
# * Weak negative non-linear relationship between SAT total score and ACT composite score for all 3 years.
#
# </ul>

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# <span style='color:blue'>
#
# In 2022, more colleges are likely to reinstate the SAT/ACT requirement for enrollment applications and more testing centres will resume operations. In preparation for this, the College Board and ACT Inc. will need to re-allocate their resources for support more testing operations.
#
# In order to improve future participation rates in SAT and ACT, the College Board and ACT Inc. should consider allocating more resources to states that meet two criteria:
#
#     1. Above average participation rate in pre-pandemic period i.e. 2019, and
#     2. Greatest decline in participation rate from 2019 to 2021.
#
# **ACT Inc. should focus on the following states:**
#
# ACT | State |Participation Rate (2019) |% Difference in participation rate (2019 to 2021) |
# --- | --- | --- | --- |
# 1 | New Mexico |0.63|-0.63|
# 2 | Arizona |0.73|-0.52|
# 3 | Oklahoma |1.00|-0.42|
# 4 | Minnesota |0.95|-0.36|
# 5 | South Carolina|0.78|-0.35|
#
# **College Board should focus on the following states:**
#
# SAT | State |Participation Rate (2019)|% Difference in participation rate (2019 to 2021) |
# --- | --- | --- | --- |
# 1 | Maine |0.99|-0.70|
# 2 | Oregon |0.51|-0.66|
# 3 | California |0.63|-0.61|
# 4 | Washington |0.70|-0.61|
# 5 | Massachusetts |0.81|-0.58|
#
# This would allow these states to bounce back to their pre-pandemic levels faster, and will likely increase the overall participation rates in the respective tests.
#
# </span>
